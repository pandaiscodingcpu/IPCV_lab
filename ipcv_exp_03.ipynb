# %%
import cv2 as cv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
img_path = '/content/zone-plate.png'
original_image = cv.imread(img_path, cv.IMREAD_GRAYSCALE)

if original_image is None:
    print(f"Error: Could not load image from {img_path}")
else:
    # Apply a Gaussian blur (low-pass filter)
    # The kernel size (e.g., (5, 5)) determines the amount of blur.
    # The standard deviation in X and Y directions (0) are automatically calculated based on kernel size.
    filtered_image = cv.GaussianBlur(original_image, (15, 15), 0)

# %%
if original_image is not None:
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image, cmap='gray')
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(filtered_image, cmap='gray')
    plt.title('Low-Pass Filtered Image (Gaussian Blur)')
    plt.axis('off')

    plt.show()
else:
    print("Cannot display images as the original image was not loaded.")

# %%
# Apply a high-pass filter using the Laplacian operator
# The Laplacian highlights regions of rapid intensity change (edges)
high_pass_filtered_image = cv.Laplacian(original_image, cv.CV_64F)

# Convert back to uint8 for display purposes, scaling if necessary
# Absolute value is often taken for Laplacian output as it can have negative values
high_pass_filtered_image = cv.convertScaleAbs(high_pass_filtered_image)

# %%
if original_image is not None:
    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(original_image, cmap='gray')
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(filtered_image, cmap='gray')
    plt.title('Low-Pass Filtered Image')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(high_pass_filtered_image, cmap='gray')
    plt.title('High-Pass Filtered Image (Laplacian)')
    plt.axis('off')

    plt.show()
else:
    print("Cannot display images as the original image was not loaded.")
